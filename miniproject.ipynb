# %%
#MINI PROJECT:Data Handling with pandas

# %%
# 🎬 Netflix Movies & TV Shows Data Analysis  

## 📖 Introduction
This project analyzes a dataset containing information about Netflix titles.  
The goal is to explore patterns, trends, and insights into the type of content available on Netflix.  

---

## 📊 Dataset Description
The dataset contains details about **movies and TV shows** on Netflix such as title, director, cast, country, release year, date added, rating, duration, and genres.  

**Number of Rows (entries):** ~ 8,800  
**Number of Columns (features):** 12  

---

## 📌 Columns Information
- **show_id** → Unique ID for each show  
- **type** → Movie or TV Show  
- **title** → Title of the content  
- **director** → Director name  
- **cast** → Actors involved  
- **country** → Country of production  
- **date_added** → Date added to Netflix  
- **release_year** → Release year of the content  
- **rating** → Audience rating (PG, R, etc.)  
- **duration** → Duration in minutes or seasons  
- **listed_in** → Genre/category  
- **description** → Short summary  

---

## 🔎 Objectives of the Analysis
- Find number of movies vs TV shows.  
- Identify the most common ratings.  
- Analyze content added over the years.  
- Explore which countries produce the most content.  
- Study most frequent genres.  

---

# %%
import pandas as pd

# %%
df=pd.read_csv("netflix.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
df.shape
# Out:
# (8807, 12)

# %%
df.isnull()
# Out:
#       show_id   type  title  director   cast  country  date_added  \
# 0       False  False  False     False   True    False       False
# 1       False  False  False      True  False    False       False
# 2       False  False  False     False  False     True       False
# 3       False  False  False      True   True     True       False
# 4       False  False  False      True  False    False       False
# ...       ...    ...    ...       ...    ...      ...         ...
# 8802    False  False  False     False  False    False       False
# 8803    False  False  False      True   True     True       False
# 8804    False  False  False     False  False    False       False
# 8805    False  False  False     False  False    False       False
# 8806    False  False  False     False  False    False       False
#
#       release_year  rating  duration  listed_in  description
# 0            False   False     False      False        False
# ...

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
clean=df.dropna()

# %%
clean.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# dtype: int64

# %%
clean.duplicated()
# Out:
# 7       False
# 8       False
# 9       False
# 12      False
# 24      False
#         ...
# 8801    False
# 8802    False
# 8804    False
# 8805    False
# 8806    False
# Length: 5332, dtype: bool

# %%
drop=clean.drop_duplicates()
drop
# Out:
#      show_id     type                          title             director  \
# 7         s8    Movie                        Sankofa         Haile Gerima
# 8         s9  TV Show  The Great British Baking Show      Andy Devonshire
# 9        s10    Movie                   The Starling       Theodore Melfi
# 12       s13    Movie                   Je Suis Karl  Christian Schwochow
# 24       s25    Movie                          Jeans           S. Shankar
# ...      ...      ...                            ...                  ...
# 8801   s8802    Movie                        Zinzana      Majid Al Ansari
# 8802   s8803    Movie                         Zodiac        David Fincher
# 8804   s8805    Movie                     Zombieland      Ruben Fleischer
# 8805   s8806    Movie                           Zoom         Peter Hewitt
# 8806   s8807    Movie                         Zubaan          Mozez Singh
#
#                                                    cast  \
# ...

# %%
drop.rename(columns={"date_added":"dateTime"},inplace=True)
drop
# Out:
#      show_id     type                          title             director  \
# 7         s8    Movie                        Sankofa         Haile Gerima
# 8         s9  TV Show  The Great British Baking Show      Andy Devonshire
# 9        s10    Movie                   The Starling       Theodore Melfi
# 12       s13    Movie                   Je Suis Karl  Christian Schwochow
# 24       s25    Movie                          Jeans           S. Shankar
# ...      ...      ...                            ...                  ...
# 8801   s8802    Movie                        Zinzana      Majid Al Ansari
# 8802   s8803    Movie                         Zodiac        David Fincher
# 8804   s8805    Movie                     Zombieland      Ruben Fleischer
# 8805   s8806    Movie                           Zoom         Peter Hewitt
# 8806   s8807    Movie                         Zubaan          Mozez Singh
#
#                                                    cast  \
# ...

# %%
drop["dateTime"]=drop["dateTime"].astype(str).str.strip()

drop["dateTime"]=pd.to_datetime(drop["dateTime"],errors='coerce')

# %%
drop["year_added"]=drop["dateTime"].dt.year

# %%
drop["month_added"]=drop["dateTime"].dt.month

# %%
drop
# Out:
#      show_id     type                          title             director  \
# 7         s8    Movie                        Sankofa         Haile Gerima
# 8         s9  TV Show  The Great British Baking Show      Andy Devonshire
# 9        s10    Movie                   The Starling       Theodore Melfi
# 12       s13    Movie                   Je Suis Karl  Christian Schwochow
# 24       s25    Movie                          Jeans           S. Shankar
# ...      ...      ...                            ...                  ...
# 8801   s8802    Movie                        Zinzana      Majid Al Ansari
# 8802   s8803    Movie                         Zodiac        David Fincher
# 8804   s8805    Movie                     Zombieland      Ruben Fleischer
# 8805   s8806    Movie                           Zoom         Peter Hewitt
# 8806   s8807    Movie                         Zubaan          Mozez Singh
#
#                                                    cast  \
# ...

# %%
drop.groupby("type").count()
# Out:
#          show_id  title  director  cast  country  dateTime  release_year  \
# type
# Movie       5185   5185      5185  5185     5185      5185          5185
# TV Show      147    147       147   147      147       147           147
#
#          rating  duration  listed_in  description  year_added  month_added
# type
# Movie      5185      5185       5185         5185        5185         5185
# TV Show     147       147        147          147         147          147

# %%
drop.groupby("country").count()
# Out:
#                                                     show_id  type  title  \
# country
# , France, Algeria                                         1     1      1
# Argentina                                                35    35     35
# Argentina, Brazil, France, Poland, Germany, Den...        1     1      1
# Argentina, Chile                                          2     2      2
# Argentina, Chile, Peru                                    1     1      1
# ...                                                     ...   ...    ...
# Uruguay, Guatemala                                        1     1      1
# Uruguay, Spain, Mexico                                    1     1      1
# Venezuela                                                 1     1      1
# Vietnam                                                   7     7      7
# Zimbabwe                                                  1     1      1
#
#                                                     director  cast  dateTime  \
# ...

# %%
list_of_countries = drop["country"].value_counts().head(10)
print(list_of_countries)
# Out:
# country
# United States     1846
# India              875
# United Kingdom     183
# Canada             107
# Spain               91
# Egypt               90
# Nigeria             88
# Japan               83
# Turkey              79
# Indonesia           76
# Name: count, dtype: int64

# %%
common_genre=drop["listed_in"].value_counts().head(10)
common_genre
# Out:
# listed_in
# Dramas, International Movies                        336
# Stand-Up Comedy                                     286
# Comedies, Dramas, International Movies              257
# Dramas, Independent Movies, International Movies    243
# Children & Family Movies, Comedies                  179
# Dramas, International Movies, Romantic Movies       160
# Documentaries                                       156
# Comedies, International Movies                      152
# Comedies, International Movies, Romantic Movies     143
# Dramas                                              133
# Name: count, dtype: int64

# %%
year_trend = df['release_year'].value_counts().sort_index()
year_trend
# Out:
# release_year
# 1925       1
# 1942       2
# 1943       3
# 1944       3
# 1945       4
#         ...
# 2017    1032
# 2018    1147
# 2019    1030
# 2020     953
# 2021     592
# Name: count, Length: 74, dtype: int64

# %%
print("Oldest title year:", drop['release_year'].min())
print("Newest title year:", drop['release_year'].max())
# Out:
# Oldest title year: 1942
# Newest title year: 2021
